# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user1

# %%
df.columns = df.columns.str.strip().str.replace('"', '')

# %%
import pandas as pd

# %%
df = pd.read_csv('cities.csv')
df
# Out:
#       LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"    EW  \
# 0                 5       59   "N"       80       39        0   "W"
# 1       42       52       48   "N"       97       23       23   "W"
# 2       46       35       59   "N"      120       30       36   "W"
# 3       42       16       12   "N"       71       48        0   "W"
# 4       43       37       48   "N"       89       46       11   "W"
# ..     ...      ...      ...   ...      ...      ...      ...   ...
# 123     39       31       12   "N"      119       48       35   "W"
# 124     50       25       11   "N"      104       39        0   "W"
# 125     40       10       48   "N"      122       14       23   "W"
# 126     40       19       48   "N"       75       55       48   "W"
# 127     41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df = df.fillna(0)
df
# Out:
#       LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"    EW  \
# 0                 5       59   "N"       80       39        0   "W"
# 1       42       52       48   "N"       97       23       23   "W"
# 2       46       35       59   "N"      120       30       36   "W"
# 3       42       16       12   "N"       71       48        0   "W"
# 4       43       37       48   "N"       89       46       11   "W"
# ..     ...      ...      ...   ...      ...      ...      ...   ...
# 123     39       31       12   "N"      119       48       35   "W"
# 124     50       25       11   "N"      104       39        0   "W"
# 125     40       10       48   "N"      122       14       23   "W"
# 126     40       19       48   "N"       75       55       48   "W"
# 127     41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"  Population
# 0          "Youngstown"       OH      302238
# 1             "Yankton"       SD       41357
# ...

# %%
import numpy as np

# %%
np.random.seed(0)
df["Population"] = np.random.randint(5000, 500000, size=len(df))
df["Area"] = np.random.uniform(10, 500, size=len(df))  # בקמ"ר

# %%
# ממוצע אוכלוסייה לפי מדינה
print(df.groupby("State")["Population"].mean())
# Out:
# State
# AL     246915.500000
# AZ     399013.000000
# BC      12877.000000
# CA     171108.333333
# CO     206576.000000
# CT     260653.000000
# DC      87457.000000
# DE     127579.000000
# FL     350249.600000
# GA     224378.500000
# IA     217529.000000
# ID     422891.000000
# IL     149241.666667
# IN     165732.500000
# KS     186704.666667
# LA     101591.000000
# MA     239618.500000
# MB     363083.000000
# MD     350135.000000
# MI     230958.500000
# MN     213727.666667
# MO     208719.500000
# MS     236378.000000
# NB     197425.000000
# NC     247449.333333
# ND     221201.500000
# NJ     204827.000000
# NM     294921.500000
# NV     238138.000000
# NY     323046.200000
# OH     454084.800000
# OH      86757.000000
# OK     143326.500000
# ON     226607.000000
# OR     264020.000000
# PA     306443.333333
# SA     329900.000000
# SC     130603.000000
# SD     391856.666667
# TX     262062.250000
# UT     310667.000000
# VA     318282.750000
# VT     343948.500000
# ...

# %%
print(df.columns)
# Out:
# Index(['LatD', 'LatM', 'LatS', 'NS', 'LonD', 'LonM', 'LonS', 'EW', 'City',
#        'State', 'Population', 'Area'],
#       dtype='object')

# %%
df.loc[df["Population"].idxmax()]
# Out:
# LatD                 41
# LatM                 50
# LatS                 59
# NS                  "N"
# LonD                 79
# LonM                  8
# LonS                 23
# EW                  "W"
# City           "Warren"
# State                PA
# Population       491221
# Area          90.820826
# Name: 27, dtype: object

# %%
df.loc[df["Population"].idxmin()]
# Out:
# LatD                    49
# LatM                    16
# LatS                    12
# NS                     "N"
# LonD                   123
# LonM                     7
# LonS                    12
# EW                     "W"
# City           "Vancouver"
# State                   BC
# Population           12877
# Area             222.31115
# Name: 33, dtype: object
